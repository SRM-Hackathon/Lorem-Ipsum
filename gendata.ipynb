# %%
import requests, json 
  
# enter your api key here 
api_key = 'AIzaSyAQLchQGNzts5ZY4PBaNnH-TzvSpqqOAz0'
  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
  
# The text string on which to search 
query = 'input=Restaurants%20in%20Chennai%20A&inputtype=textquery&locationbias=circle:100000@13.0827,80.2707&type=restaurant&fields=formatted_address,name,opening_hours,rating,place_id,types,geometry' 
  
# get method of requests module 
# return response object 
r = requests.get(url + query +
                        '&key=' + api_key) 
  
# json method of response object convert 
#  json format data into python format data 
x = r.json() 
  
# now x contains list of nested dictionaries 
# we know dictionary contain key value pair 
# store the value of result key in variable y 
y = x['results'] 
  
# keep looping upto lenght of y 
#for i in range(len(y)): 
      
    # Print value corresponding to the 
    # 'name' key at the ith index of y 
#     print(y[i]['name'])

# %%
x
# Out:
# {'error_message': 'This API project is not authorized to use this API.',
#  'html_attributions': [],
#  'results': [],
#  'status': 'REQUEST_DENIED'}

# %%
latlong-13.0827° N, 80.2707° E radius 100km

# %%
formatted_address, geometry, icon,name, permanently_closed, photos, place_id,plus_code, types,opening_hours,

# %%
import pandas as pd

# %%
df=pd.read_csv('/home/admin1/WMN/Original data.csv')

# %%
df.head()
# Out:
#      ID CATEGORY                          NAME                     PLACE_ID  \
# 0  P001    PARKS        Sri Chamarajendra Park  ChIJL2fQ53MWrjsRuN9D6aalLMY
# 1  P002    PARKS  Bannerghatta Biological Park  ChIJsW0ZC-BprjsRXzqh_3gub08
# 2  P003    PARKS               Bugle Rock Park  ChIJmwJpvowVrjsR0JVGQxxLHms
# 3  P004    PARKS    Jaya Prakash Narayana Park  ChIJ-8Jcp109rjsRe0QXmcbU8Ic
# 4  P005    PARKS         M.N. Krishna Rao Park  ChIJ4zqO6ZIVrjsRSwuhJweaVJY
#
#          LAT        LNG                                               ICON  \
# 0  12.976347  77.592928  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  12.800285  77.577047  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  12.942705  77.569429  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  13.033913  77.550009  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  12.941818  77.575248  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#    RATING                    REFERENCE  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'CATEGORY', 'NAME', 'PLACE_ID', 'LAT', 'LNG', 'ICON', 'RATING',
#        'REFERENCE', 'TYPE'],
#       dtype='object')

# %%
df=df.loc[:,['ID', 'CATEGORY', 'NAME', 'RATING']]

# %%
len(df)
# Out:
# 278

# %%
import random
l=[]
for i in range(278):
    l.append(random.randrange(1,6,1))

# %%
l
# Out:
# [3,
#  5,
#  5,
#  2,
#  1,
#  5,
#  5,
#  5,
#  1,
#  4,
#  3,
#  1,
#  1,
#  4,
#  5,
#  4,
#  1,
#  4,
#  2,
#  2,
#  3,
#  1,
#  1,
#  5,
#  5,
#  3,
#  2,
#  4,
#  3,
#  1,
#  2,
#  4,
#  3,
#  2,
#  4,
#  5,
#  2,
#  3,
#  5,
#  2,
#  2,
#  4,
#  2,
#  3,
#  5,
#  1,
#  2,
#  1,
#  1,
#  4,
#  3,
#  5,
#  5,
#  5,
#  4,
#  1,
#  1,
#  3,
#  3,
#  1,
#  1,
#  3,
#  4,
#  3,
#  4,
#  1,
#  2,
#  5,
#  4,
#  3,
#  1,
#  5,
#  5,
#  1,
#  3,
#  4,
#  1,
#  1,
#  3,
#  4,
#  2,
#  1,
#  3,
#  2,
#  5,
#  2,
#  4,
#  1,
#  3,
#  2,
#  4,
#  4,
#  3,
#  4,
#  1,
#  5,
#  3,
#  5,
#  4,
#  2,
#  1,
#  4,
#  4,
#  1,
#  3,
#  5,
#  1,
#  3,
#  2,
#  4,
#  3,
#  3,
#  5,
#  5,
#  4,
#  2,
#  4,
#  5,
#  4,
#  1,
#  5,
#  1,
#  5,
#  3,
#  1,
#  1,
#  5,
#  5,
#  4,
#  4,
#  1,
#  4,
#  4,
#  5,
#  5,
#  5,
#  1,
#  2,
#  3,
#  5,
#  3,
#  1,
#  3,
#  4,
#  2,
#  2,
#  3,
#  5,
#  4,
#  5,
#  1,
#  5,
#  1,
#  4,
#  1,
#  2,
#  5,
#  5,
#  5,
#  1,
#  4,
#  1,
#  3,
#  4,
#  3,
#  4,
# ...

# %%
df['avid']=l

# %%
df.head()
# Out:
#      ID CATEGORY                          NAME  RATING  avid
# 0  P001    PARKS        Sri Chamarajendra Park     4.4     3
# 1  P002    PARKS  Bannerghatta Biological Park     4.1     5
# 2  P003    PARKS               Bugle Rock Park     4.4     5
# 3  P004    PARKS    Jaya Prakash Narayana Park     4.4     2
# 4  P005    PARKS         M.N. Krishna Rao Park     4.4     1

# %%
df=pd.read_csv('/home/admin1/srmhack/train_data/CulturalHeritagetrain.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  user_id place_id  rating  avid
# 0           0             0   103156     P076       0     1
# 1           1             1   107362     P075       1     1
# 2           2             2   106634     P080       2     3
# 3           3             3   100112     P079       1     4
# 4           4             4   103369     P075       4     3

# %%
r=df.place_id.unique()

# %%
r=list(r)

# %%
df=pd.read_csv('/home/admin1/srmhack/Original data.csv')

# %%
df.CATEGORY.unique()
# Out:
# array(['PARKS', 'LAKES', 'HISTORICAL MONUMENT', 'GOVERNTMENT BUILDINGS',
#        'MUSEUMS', 'GALLERIES', 'WILDLIFE', 'AMUSEMENT PARKS',
#        'PLACES OF WORSHIP', 'HOTELS', 'RESTAURANTS', 'BARS',
#        'STREET FOOD', 'BAZAAR', 'SHOPPING'], dtype=object)

# %%
option= ['HISTORICAL MONUMENT', 'GOVERNTMENT BUILDINGS',
       'MUSEUMS', 'GALLERIES','PLACES OF WORSHIP']
rslt_df = df[df['CATEGORY'].isin(option)]

# %%
rslt_df = rslt_df[rslt_df['ID'].isin(list(r))]

# %%
df.columns
# Out:
# Index(['ID', 'CATEGORY', 'NAME', 'PLACE_ID', 'LAT', 'LNG', 'ICON', 'RATING',
#        'REFERENCE', 'TYPE'],
#       dtype='object')

# %%
r=list(r)

# %%
rslt_df[df['ID']=='P001']
# Out:
# /home/admin1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      ID CATEGORY                    NAME                     PLACE_ID  \
# 0  P001    PARKS  Sri Chamarajendra Park  ChIJL2fQ53MWrjsRuN9D6aalLMY
#
#          LAT        LNG                                               ICON  \
# 0  12.976347  77.592928  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#    RATING                    REFERENCE  \
# 0     4.4  ChIJL2fQ53MWrjsRuN9D6aalLMY
#
#                                              TYPE
# 0  ['park', 'point_of_interest', 'establishment']

# %%
rslt_df
# Out:
#        ID               CATEGORY  \
# 31   P032    HISTORICAL MONUMENT
# 32   P033    HISTORICAL MONUMENT
# 33   P034    HISTORICAL MONUMENT
# 34   P035    HISTORICAL MONUMENT
# 35   P036    HISTORICAL MONUMENT
# 36   P037    HISTORICAL MONUMENT
# 37   P038    HISTORICAL MONUMENT
# 38   P039  GOVERNTMENT BUILDINGS
# 39   P040  GOVERNTMENT BUILDINGS
# 40   P041  GOVERNTMENT BUILDINGS
# 41   P042  GOVERNTMENT BUILDINGS
# 42   P043  GOVERNTMENT BUILDINGS
# 43   P044                MUSEUMS
# 44   P045                MUSEUMS
# 45   P046                MUSEUMS
# 46   P047                MUSEUMS
# 47   P048                MUSEUMS
# 48   P049                MUSEUMS
# 49   P050                MUSEUMS
# 50   P051                MUSEUMS
# 51   P052                MUSEUMS
# 52   P053                MUSEUMS
# 53   P054                MUSEUMS
# 54   P055                MUSEUMS
# 55   P056                MUSEUMS
# 56   P057                MUSEUMS
# 57   P058                MUSEUMS
# ...

# %%
'P001' in r
# Out:
# True

# %%
len(r)
# Out:
# 92

# %%
z=list(rslt_df.ID.unique())
p=list(rslt_df.NAME.unique())

# %%
z.pop()
# Out:
# 'P151'

# %%
dic = {}
i=0
for key in z:
    dic[key]=p[i]
    i=i+1

# %%
dic
# Out:
# {'P032': 'Bangalore Fort',
#  'P033': 'Bangalore Palace',
#  'P034': 'Ashoka Pillar Monument',
#  'P035': "Tipu Sultan's Summer Palace",
#  'P036': 'Kempegowda Tower (South West)',
#  'P037': "Tipu Sultan's Armoury",
#  'P038': 'Devanahalli Fort',
#  'P039': 'Visvesvaraya Industrial & Technological Museum',
#  'P040': 'Victoria Hospital',
#  'P041': 'Sds Sanatorium',
#  'P042': 'Minto Ophthalmic Hospital',
#  'P043': 'Kidwai Memorial Institute of Oncology',
#  'P044': 'Government Museum',
#  'P045': 'HAL Heritage Centre and Aerospace Museum',
#  'P046': 'Venkatappa Art Gallery',
#  'P047': 'NIMHANS Brain Museum',
#  'P048': 'National Gallery of Modern Art, Bangalore',
#  'P049': 'Kempegowda Museum',
#  'P050': 'Indian Music Experience',
#  'P051': 'Indian Military Museum',
#  'P052': "Girias Children's Explorium",
#  'P053': 'Click Art Museum',
#  'P054': 'Shaswathi Womens Heritage Museum',
#  'P055': 'RAMANEEYA MUSEUM',
#  'P056': 'MKF Museum of Art',
# ...

# %%
len(p)
# Out:
# 84

# %%
len(z)
# Out:
# 92
